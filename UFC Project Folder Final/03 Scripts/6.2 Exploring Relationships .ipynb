# %% [markdown]
# ## 6.2 Exploring Relationships

# %%
#importing libraries

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
import os

# %%
# creating path

path = r'C:\Users\dequw\Documents\UFC Project Folder'

# %%
matplotlib.__version__
# Out:
# '3.7.2'

# %%
# This option ensures the charts you create are displayed in the notebook without the need to "call" them specifically.

# %matplotlib inline

# %%
#importing data set
df_UFC = pd.read_csv(os.path.join(path, 'Prepared Data UFC', 'UFC_Prepared_Data.csv'), index_col = False)

# %%
#check import of data
df_UFC.shape
# Out:
# (4954, 33)

# %%
df_UFC.columns
# Out:
# Index(['Unnamed: 0', 'r_fighter', 'b_fighter', 'date_of_fight', 'location',
#        'winner', 'weight_class', 'b_wins', 'b_losses',
#        'b_win_by_decision_majority', 'b_win_by_decision_split',
#        'b_win_by_decision_unanimous', 'b_win_by_ko/tko', 'b_win_by_submission',
#        'b_win_by_tko_doctor_stoppage', 'b_stance', 'b_height_cms',
#        'b_Reach_cms', 'b_weight_lbs', 'r_wins', 'r_losses',
#        'r_win_by_decision_majority', 'r_win_by_decision_split',
#        'r_win_by_decision_unanimous', 'r_win_by_ko/tko', 'r_win_by_submission',
#        'r_win_by_tko_doctor_stoppage', 'r_stance', 'r_height_cms',
#        'r_Reach_cms', 'r_weight_lbs', 'b_age', 'r_age'],
#       dtype='object')

# %%
df_UFC.head()
# Out:
#    Unnamed: 0      r_fighter          b_fighter date_of_fight  \
# 0           0   Adrian Yanez      Gustavo Lopez     3/20/2021
# 1           1   Trevin Giles      Roman Dolidze     3/20/2021
# 2           2    Tai Tuivasa    Harry Hunsucker     3/20/2021
# 3           3  Cheyanne Buys  Montserrat Conejo     3/20/2021
# 4           4  Marion Reneau      Macy Chiasson     3/20/2021
#
#                  location winner       weight_class  b_wins  b_losses  \
# 0  Las Vegas, Nevada, USA    Red       Bantamweight       1         1
# 1  Las Vegas, Nevada, USA    Red       Middleweight       2         0
# 2  Las Vegas, Nevada, USA    Red        Heavyweight       0         0
# 3  Las Vegas, Nevada, USA   Blue   WomenStrawweight       0         0
# 4  Las Vegas, Nevada, USA   Blue  WomenBantamweight       4         1
#
#    b_win_by_decision_majority  ...  r_win_by_decision_unanimous  \
# 0                           0  ...                            0
# ...

# %%
#remove unamed columns
df_UFC = df_UFC.drop(columns = ['Unnamed: 0'])

# %%
df_UFC.head(10)
# Out:
#          r_fighter          b_fighter date_of_fight                location  \
# 0     Adrian Yanez      Gustavo Lopez     3/20/2021  Las Vegas, Nevada, USA
# 1     Trevin Giles      Roman Dolidze     3/20/2021  Las Vegas, Nevada, USA
# 2      Tai Tuivasa    Harry Hunsucker     3/20/2021  Las Vegas, Nevada, USA
# 3    Cheyanne Buys  Montserrat Conejo     3/20/2021  Las Vegas, Nevada, USA
# 4    Marion Reneau      Macy Chiasson     3/20/2021  Las Vegas, Nevada, USA
# 5  Leonardo Santos       Grant Dawson     3/20/2021  Las Vegas, Nevada, USA
# 6       Song Kenan        Max Griffin     3/20/2021  Las Vegas, Nevada, USA
# 7    Derek Brunson      Kevin Holland     3/20/2021  Las Vegas, Nevada, USA
# 8   Montel Jackson      Jesse Strader     3/20/2021  Las Vegas, Nevada, USA
# 9       Manel Kape    Matheus Nicolau     3/13/2021  Las Vegas, Nevada, USA
#
#   winner       weight_class  b_wins  b_losses  b_win_by_decision_majority  \
# ...

# %% [markdown]
# #### 2. Exploring relationships

# %%
# creating subset
df_UFC.columns
# Out:
# Index(['r_fighter', 'b_fighter', 'date_of_fight', 'location', 'winner',
#        'weight_class', 'b_wins', 'b_losses', 'b_win_by_decision_majority',
#        'b_win_by_decision_split', 'b_win_by_decision_unanimous',
#        'b_win_by_ko/tko', 'b_win_by_submission',
#        'b_win_by_tko_doctor_stoppage', 'b_stance', 'b_height_cms',
#        'b_Reach_cms', 'b_weight_lbs', 'r_wins', 'r_losses',
#        'r_win_by_decision_majority', 'r_win_by_decision_split',
#        'r_win_by_decision_unanimous', 'r_win_by_ko/tko', 'r_win_by_submission',
#        'r_win_by_tko_doctor_stoppage', 'r_stance', 'r_height_cms',
#        'r_Reach_cms', 'r_weight_lbs', 'b_age', 'r_age'],
#       dtype='object')

# %%
df_sub = df_UFC[['b_wins', 'b_losses', 'b_height_cms',
       'b_Reach_cms', 'b_weight_lbs', 'r_wins', 'r_losses', 'r_height_cms',
       'r_Reach_cms', 'r_weight_lbs', 'b_age', 'r_age']]

# %%
df_sub.corr()
# Out:
#                 b_wins  b_losses  b_height_cms  b_Reach_cms  b_weight_lbs  \
# b_wins        1.000000  0.717588      0.125182     0.127676      0.125673
# b_losses      0.717588  1.000000      0.066011     0.061423      0.072557
# b_height_cms  0.125182  0.066011      1.000000     0.891602      0.801360
# b_Reach_cms   0.127676  0.061423      0.891602     1.000000      0.769621
# b_weight_lbs  0.125673  0.072557      0.801360     0.769621      1.000000
# r_wins        0.467496  0.287776      0.113644     0.116555      0.120798
# r_losses      0.219515  0.245909      0.085626     0.085547      0.075265
# r_height_cms  0.117954  0.070678      0.740799     0.711217      0.783988
# r_Reach_cms   0.134308  0.071166      0.715330     0.691600      0.756392
# r_weight_lbs  0.125806  0.070795      0.775511     0.745188      0.950706
# b_age         0.385582  0.435622      0.093191     0.085753      0.205737
# r_age         0.212139  0.175343      0.181780     0.172305      0.233496
#
# ...

# %%
f = plt.figure(figsize=(8, 8)) # figure size 
plt.matshow(df_sub.corr(), fignum=f.number) # type of plot
plt.xticks(range(df_sub.shape[1]), df_sub.columns, fontsize=14, rotation=45) # x axis labels
plt.yticks(range(df_sub.shape[1]), df_sub.columns, fontsize=14) # y axis labels
cb = plt.colorbar() # add a colour legend (called colorbar)
cb.ax.tick_params(labelsize=14) # add font size
plt.title('Correlation Matrix', fontsize=14) # add title
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %%
# Save figure
plt.matshow(df_sub.corr())
plt.savefig("out.png") 
# This will save the image in the working directory. 
#If you don't know what this directory is the next line will show you how to check

# %%
#current dir
cwd = os.getcwd()
cwd
# Out:
# 'C:\\Users\\dequw\\Documents\\UFC Project Folder'

# %% [markdown]
# ### Correlation Heatmap

# %%
# Create a subplot with matplotlib
f,ax = plt.subplots(figsize=(10,10))

# Create the correlation heatmap in seaborn by applying a heatmap onto the correlation matrix and the subplots defined above.
corr = sns.heatmap(df_sub.corr(), annot = True, ax = ax) # The `annot` argument allows the plot to 
#place the correlation coefficients onto the heatmap.

# %% [markdown]
# ### Scatterplots

# %%
df_UFC.columns
# Out:
# Index(['r_fighter', 'b_fighter', 'date_of_fight', 'location', 'winner',
#        'weight_class', 'b_wins', 'b_losses', 'b_win_by_decision_majority',
#        'b_win_by_decision_split', 'b_win_by_decision_unanimous',
#        'b_win_by_ko/tko', 'b_win_by_submission',
#        'b_win_by_tko_doctor_stoppage', 'b_stance', 'b_height_cms',
#        'b_Reach_cms', 'b_weight_lbs', 'r_wins', 'r_losses',
#        'r_win_by_decision_majority', 'r_win_by_decision_split',
#        'r_win_by_decision_unanimous', 'r_win_by_ko/tko', 'r_win_by_submission',
#        'r_win_by_tko_doctor_stoppage', 'r_stance', 'r_height_cms',
#        'r_Reach_cms', 'r_weight_lbs', 'b_age', 'r_age'],
#       dtype='object')

# %%
# Create a scatterplot for the "b_height_cms" and "b_Reach_cms" columns in seaborn

sns.lmplot(x = 'b_height_cms', y = 'b_Reach_cms', data = df_UFC)
# The taller the b fighter, the farther the reach
# Out:
# C:\Users\dequw\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# Create a scatterplot for the "b_height_cms" and "b_Reach_cms" columns in seaborn

sns.lmplot(x = 'r_height_cms', y = 'r_weight_lbs', data = df_UFC)
# The taller the r fighter, the heavier they are
# Out:
# C:\Users\dequw\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# Create a scatterplot for the "r_height_cms" and "b_weight_lbs" columns in seaborn

sns.lmplot(x = 'r_height_cms', y = 'b_weight_lbs', data = df_UFC)
# The taller the r fighter, the closer in weight the b fighter is
# Out:
# C:\Users\dequw\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ## Pair Plots:

# %%
# Create a pair plot 

pairplot = sns.pairplot(df_UFC)
# Out:
# C:\Users\dequw\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\dequw\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\dequw\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\dequw\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# ...

# %% [markdown]
# Based on the pair plot, it looks like most of the variables have moderate to strong relationships. I would like to epxlore further with the b_wins and R_wins to answer my question of which side is more dominant in wins. No significant outliers as this is statitistical data from live recorded fights. I also would lie to explore the r_reach_cms, b_reach_cms, r_weight_lb, b_weight_lb,r_stance and b_stance as they will provide deeper entail on wins and losses along with r_age and b_age.

# %%
#Export viz
pairplot.figure.savefig(os.path.join(path, 'Visualizations', 'pairplot.png'))

# %% [markdown]
# ## Categorical Plot

# %%
sns.histplot(df_UFC['r_Reach_cms'],bins = 20, kde = True)
# Out:
# C:\Users\dequw\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\dequw\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='r_Reach_cms', ylabel='Count'>

# %%
#Apply flags
df_UFC.loc[df_UFC['r_Reach_cms'] < 170, 'r_fighter_reach'] = 'Low reach'

# %%
df_UFC.loc[(df_UFC['r_Reach_cms'] >= 170) & (df_UFC['r_Reach_cms'] < 200), 'r_fighter_reach'] = 'Middle reach'

# %%
df_UFC.loc[df_UFC['r_Reach_cms'] >= 200, 'r_fighter_reach'] = 'High reach'

# %%
df_UFC['r_fighter_reach'].value_counts(dropna = False)
# Out:
# r_fighter_reach
# Middle reach    4108
# Low reach        519
# High reach       327
# Name: count, dtype: int64

# %%
df_UFC.columns
# Out:
# Index(['r_fighter', 'b_fighter', 'date_of_fight', 'location', 'winner',
#        'weight_class', 'b_wins', 'b_losses', 'b_win_by_decision_majority',
#        'b_win_by_decision_split', 'b_win_by_decision_unanimous',
#        'b_win_by_ko/tko', 'b_win_by_submission',
#        'b_win_by_tko_doctor_stoppage', 'b_stance', 'b_height_cms',
#        'b_Reach_cms', 'b_weight_lbs', 'r_wins', 'r_losses',
#        'r_win_by_decision_majority', 'r_win_by_decision_split',
#        'r_win_by_decision_unanimous', 'r_win_by_ko/tko', 'r_win_by_submission',
#        'r_win_by_tko_doctor_stoppage', 'r_stance', 'r_height_cms',
#        'r_Reach_cms', 'r_weight_lbs', 'b_age', 'r_age', 'r_fighter_reach',
#        'Price category'],
#       dtype='object')

# %%
# Create a categorical plot in seaborn using the reach categories created above

sns.set(style="ticks")
g = sns.catplot(x="r_age", y="r_Reach_cms", hue="r_fighter_reach", data=df_UFC)
# Out:
# C:\Users\dequw\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\dequw\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\dequw\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\dequw\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# ...

# %%
# Create a categorical plot in seaborn using the reach categories created above
sns.set(style="ticks")
g = sns.catplot(x="r_win_by_decision_unanimous", y="r_Reach_cms", hue="r_fighter_reach", data=df_UFC)
# Out:
# C:\Users\dequw\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\dequw\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\dequw\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\dequw\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# ...

# %% [markdown]
# Low reach category has less wins on redside where as middle reach has more wins which is possible due to the abundance of middle reach fighters. High Reach fighters on red side have just as many unanimous wins as low reach fighters.
#
# New question: Does red reach middle has as much wins as blue reach fights?

# %%
# fig = g.get_figure()
g.savefig("out.png") 

# Again, the image will be saved in the working directory.
